# %%
# !cat /root/.kaggle/kaggle.json

# %%
# !pip install -q transformers

# %%
import torch
from transformers import ViTFeatureExtractor, ViTForImageClassification
from transformers import AutoFeatureExtractor, AutoModelForImageClassification
from PIL import Image

# %%
model_checkpoint = "facebook/convnextv2-base-22k-224"

# %%
import os

# %%
# !ls

# %%
# !pwd

# %%
# !pip install -Uq datasets

# %%
import os  # Import the os module

# Now you can use os.path.join() function
trainpath = os.path.join("/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/train",'**')

# %%
testpath=  os.path.join("/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test","**")

# %%
from datasets import load_dataset 
dataset = load_dataset("imagefolder", data_files={"train": trainpath, "test": testpath})

# %%
dataset

# %%
dataset["train"].features

# %%
example = dataset["train"][0]

# %%
example['image']

# %%
example['image'].resize((200, 200))

# %%
dataset["train"].features["label"]
labels = dataset["train"].features["label"].names

# %%
print(labels)

# %%
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

id2label[1]

# %%
from transformers import AutoImageProcessor

image_processor  = AutoImageProcessor.from_pretrained(model_checkpoint)
image_processor

# %%
from torchvision.transforms import (
    CenterCrop,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    Resize,
    ToTensor,
)

normalize = Normalize(mean=image_processor.image_mean, std=image_processor.image_std)
if "height" in image_processor.size:
    size = (image_processor.size["height"], image_processor.size["width"])
    crop_size = size
    max_size = None
elif "shortest_edge" in image_processor.size:
    size = image_processor.size["shortest_edge"]
    crop_size = (size, size)
    max_size = image_processor.size.get("longest_edge")

train_transforms = Compose(
        [
            RandomResizedCrop(crop_size),
            RandomHorizontalFlip(),
            ToTensor(),
            normalize,
        ]
    )

val_transforms = Compose(
        [
            Resize(size),
            CenterCrop(crop_size),
            ToTensor(),
            normalize,
        ]
    )

def preprocess_train(example_batch):
    """Apply train_transforms across a batch."""
    example_batch["pixel_values"] = [
        train_transforms(image.convert("RGB")) for image in example_batch["image"]
    ]
    return example_batch

def preprocess_val(example_batch):
    """Apply val_transforms across a batch."""
    example_batch["pixel_values"] = [val_transforms(image.convert("RGB")) for image in example_batch["image"]]
    return example_batch

# %%
train_ds = dataset['train']

# %%
test_ds = dataset['test']

# %%
train_ds.set_transform(preprocess_train)
test_ds.set_transform(preprocess_val)

# %%
train_ds[0]

# %%
from transformers import AutoModelForImageClassification, TrainingArguments, Trainer

model = AutoModelForImageClassification.from_pretrained(
    model_checkpoint, 
    label2id=label2id,
    id2label=id2label,
    ignore_mismatched_sizes = True, # provide this in case you're planning to fine-tune an already fine-tuned checkpoint
)

# %%
batch_size=16

# %%
model_name = model_checkpoint.split("/")[-1]

args = TrainingArguments(
    f"{model_name}-BASE",
    remove_unused_columns=False,
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=batch_size,
    gradient_accumulation_steps=1,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    logging_steps=10,
    warmup_ratio=0.1,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    report_to="none"
)

# %%
from datasets import list_metrics

# %%
list_metrics()

# %%
from datasets import load_metric

metric1 = load_metric("accuracy")
metric2 = load_metric("recall")
metric3 = load_metric("f1")

# %%
import numpy as np

# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    labels = eval_pred.label_ids
    accuracy = metric1.compute(predictions=predictions, references=labels)['accuracy']
    recall = metric2.compute(predictions=predictions, references=labels)['recall']
    f1 = metric3.compute(predictions=predictions, references=labels)['f1']
    return {"accuracy": accuracy,"recall": recall, "f1": f1}

# %%
import torch

def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    tokenizer=image_processor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)

# %%
train_results = trainer.train()
# rest is optional but nice to have
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()

# %%
metrics = trainer.evaluate()
# some nice to haves:
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)

# %%
# !mkdir data

# %%
# !cp -r "/kaggle/input/test-train" data/

# %%
import os
x=os.listdir("/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding")

# %%
y= x[:10]

# %%
y

# %%
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (853).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (1046).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (609).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (1134).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (262).png" .
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (539).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (812).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (612).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (1256).png" . 
# !cp "/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/img- (234).png" .

# %%
for i in y:
    os.remove("/kaggle/working/data/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/"+i)

# %%
from transformers import pipeline

# %%
from PIL import Image

# %%
import requests

# %%
image = Image.open("/kaggle/working/img- (234).png")

# %%
pip install torch torchvision torchaudio -f https://download.pytorch.org/whl/cu111/torch_stable.html

# %%
pipe = pipeline("image-classification", 
                model=model,
                feature_extractor=image_processor, device=0)

# %%
pipe(image)

# %%
from transformers import AutoConfig, AutoModelForImageClassification, AutoImageProcessor

# %%
config = AutoConfig.from_pretrained("/kaggle/working/convnextv2-atto-1k-224-ATTO/checkpoint-198/config.json")

# %%
model = AutoModelForImageClassification.from_pretrained(
    "/kaggle/working/convnextv2-atto-1k-224-ATTO/checkpoint-198/", config=config
)

# %%
image_processor  = AutoImageProcessor.from_pretrained("/kaggle/working/convnextv2-atto-1k-224-ATTO/checkpoint-198/")

# %%
from PIL import Image
image = Image.open("/kaggle/working/data/test-train/WCEBleedGen/Images/bleeding/img- (1248).png")

# %%
encoding = image_processor(image.convert("RGB"), return_tensors="pt").to("cuda")

# %%
encoding

# %%
import torch

# forward pass
with torch.no_grad():
    outputs = model(**encoding)
    logits = outputs.logits

# %%
logits

# %%
torch.nn.functional.softmax(logits, dim=1)[0, 0]

# %%
predicted_class_idx = logits.argmax(-1).item()

# %%
predicted_class_idx

# %%
model.config.id2label

# %%
logits.argsort()[0][-5:]

# %%
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])

# %%
# !pip install omnixai

# %%
# !pip install lime
# Out:
# Requirement already satisfied: lime in /opt/conda/lib/python3.10/site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from lime) (3.7.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lime) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lime) (1.11.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lime) (4.66.1)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from lime) (1.2.2)
# Requirement already satisfied: scikit-image>=0.12 in /opt/conda/lib/python3.10/site-packages (from lime) (0.21.0)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.12->lime) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->lime) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->lime) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->lime) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->lime) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->lime) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->lime) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)

# %%
# !pip uninstall numpy -y
# Out:
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5

# %%
# !python3 -m pip install scikit-learn==1.1.3

# %%
import scipy

# %%
from lime import lime_image
explainer = lime_image.LimeImageExplainer()

# %%
print(scipy.__version__)
# Out:
# 1.7.3

# %%
pipe = pipeline("image-classification", 
                model=model,
                feature_extractor=image_processor)

# %%
temp_images = [Image.open("/kaggle/working/data/test-train/WCEBleedGen/Images/bleeding/img- (1248).png"), Image.open("/kaggle/working/data/test-train/WCEBleedGen/Images/bleeding/img- (1248).png")]

# %%
pipe([Image.open("/kaggle/working/data/test-train/WCEBleedGen/Images/bleeding/img- (1248).png"), Image.open("/kaggle/working/data/test-train/WCEBleedGen/Images/bleeding/img- (1248).png")])

# %%
def batchpredict(images):
    batch = [image_processor(img, return_tensors="pt") for img in images]
    with torch.no_grad():
        outputs = [model(**b) for b in batch]
        logits = [torch.nn.functional.softmax(o.logits, dim=1) for o in outputs]
        return torch.cat(logits).detach().cpu().numpy()

# %%
batchpredict(temp_images)

# %%
for x in batchpredict(temp_images).argsort()[0][-5:]:
    print( x, model.config.id2label[x], batchpredict(temp_images)[0,x])

# %%
import numpy as np
limetestimage = [np.array(Image.open("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/A0040.png").convert('RGB'), )]

# %%
limetestimage.shape = (224, 224, 3)

# %%
explanation = explainer.explain_instance(limetestimage, batchpredict, top_labels=2, hide_color=0, num_samples=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[295], line 1
# ----> 1 explanation = explainer.explain_instance(limetestimage, batchpredict, top_labels=2, hide_color=0, num_samples=1000)
#
# File /opt/conda/lib/python3.10/site-packages/lime/lime_image.py:198, in LimeImageExplainer.explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     194     fudged_image[:] = hide_color
#     196 top = labels
# --> 198 data, labels = self.data_labels(image, fudged_image, segments,
#     199                                 classifier_fn, num_samples,
#     200                                 batch_size=batch_size)
#     202 distances = sklearn.metrics.pairwise_distances(
#     203     data,
#     204     data[0].reshape(1, -1),
#     205     metric=distance_metric
#     206 ).ravel()
#     208 ret_exp = ImageExplanation(image, segments)
#
# File /opt/conda/lib/python3.10/site-packages/lime/lime_image.py:261, in LimeImageExplainer.data_labels(self, image, fudged_image, segments, classifier_fn, num_samples, batch_size)
#     259 imgs.append(temp)
#     260 if len(imgs) == batch_size:
# --> 261     preds = classifier_fn(np.array(imgs))
#     262     labels.extend(preds)
#     263     imgs = []
#
# Cell In[293], line 4, in batchpredict(images)
#       2 batch = [image_processor(img, return_tensors="pt") for img in images]
#       3 with torch.no_grad():
# ----> 4     outputs = [model(**b) for b in batch]
#       5     logits = [torch.nn.functional.softmax(o.logits, dim=1) for o in outputs]
#       6     return torch.cat(logits).detach().cpu().numpy()
#
# Cell In[293], line 4, in <listcomp>(.0)
#       2 batch = [image_processor(img, return_tensors="pt") for img in images]
#       3 with torch.no_grad():
# ----> 4     outputs = [model(**b) for b in batch]
#       5     logits = [torch.nn.functional.softmax(o.logits, dim=1) for o in outputs]
#       6     return torch.cat(logits).detach().cpu().numpy()
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/convnextv2/modeling_convnextv2.py:458, in ConvNextV2ForImageClassification.forward(self, pixel_values, labels, output_hidden_states, return_dict)
#     450 r"""
#     451 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     452     Labels for computing the image classification/regression loss. Indices should be in `[0, ...,
#     453     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     454     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     455 """
#     456 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 458 outputs = self.convnextv2(pixel_values, output_hidden_states=output_hidden_states, return_dict=return_dict)
#     460 pooled_output = outputs.pooler_output if return_dict else outputs[1]
#     462 logits = self.classifier(pooled_output)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/convnextv2/modeling_convnextv2.py:392, in ConvNextV2Model.forward(self, pixel_values, output_hidden_states, return_dict)
#     388     raise ValueError("You have to specify pixel_values")
#     390 embedding_output = self.embeddings(pixel_values)
# --> 392 encoder_outputs = self.encoder(
#     393     embedding_output,
#     394     output_hidden_states=output_hidden_states,
#     395     return_dict=return_dict,
#     396 )
#     398 last_hidden_state = encoder_outputs[0]
#     400 # global average pooling, (N, C, H, W) -> (N, C)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/convnextv2/modeling_convnextv2.py:282, in ConvNextV2Encoder.forward(self, hidden_states, output_hidden_states, return_dict)
#     279     if output_hidden_states:
#     280         all_hidden_states = all_hidden_states + (hidden_states,)
# --> 282     hidden_states = layer_module(hidden_states)
#     284 if output_hidden_states:
#     285     all_hidden_states = all_hidden_states + (hidden_states,)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/convnextv2/modeling_convnextv2.py:244, in ConvNextV2Stage.forward(self, hidden_states)
#     242 def forward(self, hidden_states: torch.FloatTensor) -> torch.Tensor:
#     243     hidden_states = self.downsampling_layer(hidden_states)
# --> 244     hidden_states = self.layers(hidden_states)
#     245     return hidden_states
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/transformers/models/convnextv2/modeling_convnextv2.py:207, in ConvNextV2Layer.forward(self, hidden_states)
#     205 x = self.act(x)
#     206 x = self.grn(x)
# --> 207 x = self.pwconv2(x)
#     208 # (batch_size, height, width, num_channels) -> (batch_size, num_channels, height, width)
#     209 x = x.permute(0, 3, 1, 2)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
from skimage.segmentation import mark_boundaries

# %%
import matplotlib.pyplot as plt
temp, mask = explanation.get_image_and_mask(0, positive_only=True, num_features=2, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
import matplotlib.pyplot as plt
temp, mask = explanation.get_image_and_mask(1, positive_only=True, num_features=2, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
Image.open("/kaggle/working/data/test-train/WCEBleedGen/Images/bleeding/img- (1069).png")

# %%
temp, mask = explanation.get_image_and_mask(0, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %%
test1dict = {}
def predict(images):
    encoding = image_processor(images.convert("RGB"), return_tensors="pt")
    with torch.no_grad():
        outputs = model(**encoding) 
        logits = outputs.logits
        prob = torch.nn.functional.softmax(logits, dim=1)
        test1dict[images.filename.split('/')[-1]] = [model.config.id2label[logits.argmax(-1).item()], prob.detach().cpu().squeeze().tolist()]
        return 0

# %%
import os
from PIL import Image
import torch
z = os.listdir("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/")
for a in z:
    img = Image.open("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/"+a)
    predict(img)

# %%
test1dict
# Out:
# {'A0028.png': ['non-bleeding', [0.00656186742708087, 0.9934380650520325]],
#  'A0016.png': ['non-bleeding', [0.0008446004940196872, 0.9991554021835327]],
#  'A0046.png': ['non-bleeding', [0.0240397397428751, 0.9759603142738342]],
#  'A0041.png': ['non-bleeding', [0.0008005812996998429, 0.9991994500160217]],
#  'A0023.png': ['non-bleeding', [0.027021873742341995, 0.9729781746864319]],
#  'A0042.png': ['bleeding', [0.9985209107398987, 0.0014791081193834543]],
#  'A0038.png': ['bleeding', [0.9861766695976257, 0.013823379762470722]],
#  'A0007.png': ['non-bleeding', [0.05690043047070503, 0.9430996179580688]],
#  'A0044.png': ['non-bleeding', [0.001440991647541523, 0.9985590577125549]],
#  'A0002.png': ['bleeding', [0.9997251629829407, 0.00027481705183163285]],
#  'A0040.png': ['bleeding', [0.9803436994552612, 0.019656337797641754]],
#  'A0019.png': ['non-bleeding', [0.001256388146430254, 0.9987435936927795]],
#  'A0021.png': ['non-bleeding', [0.41142430901527405, 0.5885757207870483]],
#  'A0037.png': ['bleeding', [0.9985523819923401, 0.0014476231299340725]],
#  'A0011.png': ['non-bleeding', [0.013193822465837002, 0.9868061542510986]],
#  'A0026.png': ['bleeding', [0.9964128136634827, 0.0035872431471943855]],
#  'A0008.png': ['non-bleeding', [0.00044286641059443355, 0.9995570778846741]],
#  'A0035.png': ['non-bleeding', [0.24079987406730652, 0.7592001557350159]],
#  'A0017.png': ['non-bleeding', [0.01181632187217474, 0.9881836771965027]],
#  'A0013.png': ['non-bleeding', [0.001196212018840015, 0.9988037347793579]],
#  'A0018.png': ['non-bleeding', [0.005590747110545635, 0.9944092631340027]],
#  'A0012.png': ['non-bleeding', [0.0018312397878617048, 0.9981687068939209]],
#  'A0029.png': ['non-bleeding', [0.003584065707400441, 0.9964159727096558]],
#  'A0039.png': ['bleeding', [0.9442684650421143, 0.05573156848549843]],
#  'A0034.png': ['bleeding', [0.9998767375946045, 0.0001232947106473148]],
#  'A0048.png': ['non-bleeding', [0.0003166176611557603, 0.9996833801269531]],
#  'A0043.png': ['bleeding', [0.9977849721908569, 0.002215039450675249]],
#  'A0014.png': ['non-bleeding', [0.010961567983031273, 0.9890384674072266]],
#  'A0049.png': ['non-bleeding', [0.000119657204777468, 0.999880313873291]],
#  'A0045.png': ['non-bleeding', [0.0011896573705598712, 0.9988104104995728]],
#  'A0032.png': ['bleeding', [0.989303708076477, 0.010696244426071644]],
#  'A0025.png': ['bleeding', [0.9012473821640015, 0.09875260293483734]],
#  'A0027.png': ['bleeding', [0.9976200461387634, 0.002379890065640211]],
#  'A0006.png': ['non-bleeding', [0.2068430632352829, 0.7931568622589111]],
#  'A0003.png': ['non-bleeding', [0.0005724838702008128, 0.9994275569915771]],
#  'A0030.png': ['non-bleeding', [0.010952848941087723, 0.989047110080719]],
#  'A0005.png': ['non-bleeding', [0.0010998807847499847, 0.9989000558853149]],
#  'A0009.png': ['non-bleeding', [0.000924397842027247, 0.9990755319595337]],
#  'A0004.png': ['non-bleeding', [0.00997219979763031, 0.9900278449058533]],
#  'A0020.png': ['non-bleeding', [0.41419294476509094, 0.5858070254325867]],
#  'A0001.png': ['non-bleeding', [0.015707630664110184, 0.9842923879623413]],
#  'A0022.png': ['non-bleeding', [0.05832308158278465, 0.9416769742965698]],
#  'A0000.png': ['bleeding', [0.9997746348381042, 0.0002254223800264299]],
#  'A0024.png': ['non-bleeding', [0.004980152007192373, 0.995019793510437]],
#  'A0036.png': ['bleeding', [0.9938283562660217, 0.006171696819365025]],
#  'A0031.png': ['non-bleeding', [0.43158939480781555, 0.5684106349945068]],
#  'A0033.png': ['bleeding', [0.9981075525283813, 0.0018924420000985265]],
#  'A0010.png': ['bleeding', [0.9646692872047424, 0.03533065691590309]],
#  'A0047.png': ['non-bleeding', [0.008846226148307323, 0.9911537766456604]]}

# %%
Image.open("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/A0034.png")

# %%
def custom_sort_key(item):
    return max(item[1][1])
sorted_dict1 = dict(sorted(test1dict.items(), key=custom_sort_key, reverse=True))
print(sorted_dict1)
# Out:
# {'A0049.png': ['non-bleeding', [0.000119657204777468, 0.999880313873291]], 'A0034.png': ['bleeding', [0.9998767375946045, 0.0001232947106473148]], 'A0000.png': ['bleeding', [0.9997746348381042, 0.0002254223800264299]], 'A0002.png': ['bleeding', [0.9997251629829407, 0.00027481705183163285]], 'A0048.png': ['non-bleeding', [0.0003166176611557603, 0.9996833801269531]], 'A0008.png': ['non-bleeding', [0.00044286641059443355, 0.9995570778846741]], 'A0003.png': ['non-bleeding', [0.0005724838702008128, 0.9994275569915771]], 'A0041.png': ['non-bleeding', [0.0008005812996998429, 0.9991994500160217]], 'A0016.png': ['non-bleeding', [0.0008446004940196872, 0.9991554021835327]], 'A0009.png': ['non-bleeding', [0.000924397842027247, 0.9990755319595337]], 'A0005.png': ['non-bleeding', [0.0010998807847499847, 0.9989000558853149]], 'A0045.png': ['non-bleeding', [0.0011896573705598712, 0.9988104104995728]], 'A0013.png': ['non-bleeding', [0.001196212018840015, 0.9988037347793579]], 'A0019.png': ['non-bleeding', [0.001256388146430254, 0.9987435936927795]], 'A0044.png': ['non-bleeding', [0.001440991647541523, 0.9985590577125549]], 'A0037.png': ['bleeding', [0.9985523819923401, 0.0014476231299340725]], 'A0042.png': ['bleeding', [0.9985209107398987, 0.0014791081193834543]], 'A0012.png': ['non-bleeding', [0.0018312397878617048, 0.9981687068939209]], 'A0033.png': ['bleeding', [0.9981075525283813, 0.0018924420000985265]], 'A0043.png': ['bleeding', [0.9977849721908569, 0.002215039450675249]], 'A0027.png': ['bleeding', [0.9976200461387634, 0.002379890065640211]], 'A0029.png': ['non-bleeding', [0.003584065707400441, 0.9964159727096558]], 'A0026.png': ['bleeding', [0.9964128136634827, 0.0035872431471943855]], 'A0024.png': ['non-bleeding', [0.004980152007192373, 0.995019793510437]], 'A0018.png': ['non-bleeding', [0.005590747110545635, 0.9944092631340027]], 'A0036.png': ['bleeding', [0.9938283562660217, 0.006171696819365025]], 'A0028.png': ['non-bleeding', [0.00656186742708087, 0.9934380650520325]], 'A0047.png': ['non-bleeding', [0.008846226148307323, 0.9911537766456604]], 'A0004.png': ['non-bleeding', [0.00997219979763031, 0.9900278449058533]], 'A0032.png': ['bleeding', [0.989303708076477, 0.010696244426071644]], 'A0030.png': ['non-bleeding', [0.010952848941087723, 0.989047110080719]], 'A0014.png': ['non-bleeding', [0.010961567983031273, 0.9890384674072266]], 'A0017.png': ['non-bleeding', [0.01181632187217474, 0.9881836771965027]], 'A0011.png': ['non-bleeding', [0.013193822465837002, 0.9868061542510986]], 'A0038.png': ['bleeding', [0.9861766695976257, 0.013823379762470722]], 'A0001.png': ['non-bleeding', [0.015707630664110184, 0.9842923879623413]], 'A0040.png': ['bleeding', [0.9803436994552612, 0.019656337797641754]], 'A0046.png': ['non-bleeding', [0.0240397397428751, 0.9759603142738342]], 'A0023.png': ['non-bleeding', [0.027021873742341995, 0.9729781746864319]], 'A0010.png': ['bleeding', [0.9646692872047424, 0.03533065691590309]], 'A0039.png': ['bleeding', [0.9442684650421143, 0.05573156848549843]], 'A0007.png': ['non-bleeding', [0.05690043047070503, 0.9430996179580688]], 'A0022.png': ['non-bleeding', [0.05832308158278465, 0.9416769742965698]], 'A0025.png': ['bleeding', [0.9012473821640015, 0.09875260293483734]], 'A0006.png': ['non-bleeding', [0.2068430632352829, 0.7931568622589111]], 'A0035.png': ['non-bleeding', [0.24079987406730652, 0.7592001557350159]], 'A0021.png': ['non-bleeding', [0.41142430901527405, 0.5885757207870483]], 'A0020.png': ['non-bleeding', [0.41419294476509094, 0.5858070254325867]], 'A0031.png': ['non-bleeding', [0.43158939480781555, 0.5684106349945068]]}

# %%
try: 
    probtest1 = open('probtest1.txt', 'wt') 
    probtest1.write(str(sorted_dict1)) 
    probtest1.close() 
  
except: 
    print("Unable to write to file")

# %%
i = 0
for test_name, prob_name in sorted_dict1.items():
    if i <5:
        print(test_name, prob_name)
        i = i+1

# %%
w = os.listdir("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2")
for a in w:
    img = Image.open("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/"+a)
    predict(img)

# %%
def custom_sort_key(item):
    return max(item[1])
sorted_dict2 = dict(sorted(test1dict.items(), key=custom_sort_key, reverse=True))
print(sorted_dict2)

# %%
i = 0
for test_name, prob_name in sorted_dict2.items():
    if i <10:
        print(test_name, prob_name)
        i = i+1

# %%
try: 
    probtest2 = open('probtest2.txt', 'wt') 
    probtest2.write(str(sorted_dict2)) 
    probtest2.close() 
  
except: 
    print("Unable to write to file")

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.195-py3-none-any.whl (618 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 13.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.2)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.0.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.15.1+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.195

# %%
# !mkdir dataset
# !mkdir dataset/images
# !mkdir dataset/labels
# !mkdir dataset/images/train
# !mkdir dataset/images/val
# !mkdir dataset/labels/train
# !mkdir dataset/labels/val
# !cp -r /kaggle/input/wcettcc/WCEBleedGen/WCEBleedGen/Train_Test_Folder/train/bleeding/. /kaggle/working/dataset/images/train/
# !cp -r /kaggle/input/wcettcc/WCEBleedGen/WCEBleedGen/Train_Test_Folder/test/bleeding/. /kaggle/working/dataset/images/val/
import shutil
import os
trainimagedataset = os.listdir("/kaggle/working/dataset/images/train/")
valimagedataset = os.listdir("/kaggle/working/dataset/images/val/")
count = 0

for y in os.listdir("/kaggle/input/wcettcc/WCEBleedGen/WCEBleedGen/WCEBleedGen/bleeding/Bounding boxes/YOLO_TXT"):
    if((y.split('.')[0]+".png") in valimagedataset):
        count = count+1
        shutil.copy(("/kaggle/input/wcettcc/WCEBleedGen/WCEBleedGen/WCEBleedGen/bleeding/Bounding boxes/YOLO_TXT/"+y), ("/kaggle/working/dataset/labels/val/"))
#     print(y.split('.')[0]+".png")
print(count)
count = 0
for y in os.listdir("/kaggle/input/wcettcc/WCEBleedGen/WCEBleedGen/WCEBleedGen/bleeding/Bounding boxes/YOLO_TXT"):
    if((y.split('.')[0]+".png") in trainimagedataset):
        count = count+1
        shutil.copy(("/kaggle/input/wcettcc/WCEBleedGen/WCEBleedGen/WCEBleedGen/bleeding/Bounding boxes/YOLO_TXT/"+y), ("/kaggle/working/dataset/labels/train/"))
#     print(y.split('.')[0]+".png")
print(count)
# Out:
# 262
# 1047

# %%
# %%writefile dataset/config.yaml
# path: /kaggle/working/dataset
# train: /kaggle/working/dataset/images/train
# val: /kaggle/working/dataset/images/val
#
# nc: 1
# names:
#   0: bleeding
# Out:
# Writing dataset/config.yaml

# %% [markdown]
# # FINALISING BOTH MODELS

# %%
from transformers import AutoConfig, AutoModelForImageClassification, AutoImageProcessor
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
config = AutoConfig.from_pretrained("/kaggle/working/convnextv2-base-22k-224-BASE/config.json")

# %%
model = AutoModelForImageClassification.from_pretrained(
    "/kaggle/working/convnextv2-base-22k-224-BASE/checkpoint-198", config=config
)

# %%
model.config.id2label
# Out:
# {0: 'bleeding', 1: 'non-bleeding'}

# %%
image_processor  = AutoImageProcessor.from_pretrained("/kaggle/working/convnextv2-base-22k-224-BASE/checkpoint-198")

# %%
test2dict = {}
def predict_conv(images):
    encoding = image_processor(images.convert("RGB"), return_tensors="pt")
    with torch.no_grad():
        outputs = model(**encoding) 
        logits = outputs.logits
        prob = torch.nn.functional.softmax(logits, dim=1)
        test2dict[images.filename.split('/')[-1]] = [model.config.id2label[logits.argmax(-1).item()], prob.detach().cpu().squeeze().tolist()]
        return prob, model.config.id2label[logits.argmax(-1).item()]
import os
from PIL import Image
import torch
z = os.listdir("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/")
for a in z:
    img = Image.open("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/"+a)
    predict_conv(img)
def custom_sort_key(item):
    return max(item[1][1])
sorted_dict2 = dict(sorted(test2dict.items(), key=custom_sort_key, reverse=True))

# %%
toChange = 'img- (592).png'
finaltesting = Image.open("/kaggle/input/test-train/WCEBleedGen/Train_Test_Folder/test/bleeding/"+toChange)

# %%
predict_conv(finaltesting)
# Out:
# (tensor([[9.9995e-01, 4.5772e-05]]), 'bleeding')

# %%
print(sorted_dict2)
# Out:
# {'A0049.png': ['non-bleeding', [0.000119657204777468, 0.999880313873291]], 'A0034.png': ['bleeding', [0.9998767375946045, 0.0001232947106473148]], 'A0000.png': ['bleeding', [0.9997746348381042, 0.0002254223800264299]], 'A0002.png': ['bleeding', [0.9997251629829407, 0.00027481705183163285]], 'A0048.png': ['non-bleeding', [0.0003166176611557603, 0.9996833801269531]], 'A0008.png': ['non-bleeding', [0.00044286641059443355, 0.9995570778846741]], 'A0003.png': ['non-bleeding', [0.0005724838702008128, 0.9994275569915771]], 'A0041.png': ['non-bleeding', [0.0008005812996998429, 0.9991994500160217]], 'A0016.png': ['non-bleeding', [0.0008446004940196872, 0.9991554021835327]], 'A0009.png': ['non-bleeding', [0.000924397842027247, 0.9990755319595337]], 'A0005.png': ['non-bleeding', [0.0010998807847499847, 0.9989000558853149]], 'A0045.png': ['non-bleeding', [0.0011896573705598712, 0.9988104104995728]], 'A0013.png': ['non-bleeding', [0.001196212018840015, 0.9988037347793579]], 'A0019.png': ['non-bleeding', [0.001256388146430254, 0.9987435936927795]], 'A0044.png': ['non-bleeding', [0.001440991647541523, 0.9985590577125549]], 'A0037.png': ['bleeding', [0.9985523819923401, 0.0014476231299340725]], 'A0042.png': ['bleeding', [0.9985209107398987, 0.0014791081193834543]], 'A0012.png': ['non-bleeding', [0.0018312397878617048, 0.9981687068939209]], 'A0033.png': ['bleeding', [0.9981075525283813, 0.0018924420000985265]], 'A0043.png': ['bleeding', [0.9977849721908569, 0.002215039450675249]], 'A0027.png': ['bleeding', [0.9976200461387634, 0.002379890065640211]], 'A0029.png': ['non-bleeding', [0.003584065707400441, 0.9964159727096558]], 'A0026.png': ['bleeding', [0.9964128136634827, 0.0035872431471943855]], 'A0024.png': ['non-bleeding', [0.004980152007192373, 0.995019793510437]], 'A0018.png': ['non-bleeding', [0.005590747110545635, 0.9944092631340027]], 'A0036.png': ['bleeding', [0.9938283562660217, 0.006171696819365025]], 'A0028.png': ['non-bleeding', [0.00656186742708087, 0.9934380650520325]], 'A0047.png': ['non-bleeding', [0.008846226148307323, 0.9911537766456604]], 'A0004.png': ['non-bleeding', [0.00997219979763031, 0.9900278449058533]], 'A0032.png': ['bleeding', [0.989303708076477, 0.010696244426071644]], 'A0030.png': ['non-bleeding', [0.010952848941087723, 0.989047110080719]], 'A0014.png': ['non-bleeding', [0.010961567983031273, 0.9890384674072266]], 'A0017.png': ['non-bleeding', [0.01181632187217474, 0.9881836771965027]], 'A0011.png': ['non-bleeding', [0.013193822465837002, 0.9868061542510986]], 'A0038.png': ['bleeding', [0.9861766695976257, 0.013823379762470722]], 'A0001.png': ['non-bleeding', [0.015707630664110184, 0.9842923879623413]], 'A0040.png': ['bleeding', [0.9803436994552612, 0.019656337797641754]], 'A0046.png': ['non-bleeding', [0.0240397397428751, 0.9759603142738342]], 'A0023.png': ['non-bleeding', [0.027021873742341995, 0.9729781746864319]], 'A0010.png': ['bleeding', [0.9646692872047424, 0.03533065691590309]], 'A0039.png': ['bleeding', [0.9442684650421143, 0.05573156848549843]], 'A0007.png': ['non-bleeding', [0.05690043047070503, 0.9430996179580688]], 'A0022.png': ['non-bleeding', [0.05832308158278465, 0.9416769742965698]], 'A0025.png': ['bleeding', [0.9012473821640015, 0.09875260293483734]], 'A0006.png': ['non-bleeding', [0.2068430632352829, 0.7931568622589111]], 'A0035.png': ['non-bleeding', [0.24079987406730652, 0.7592001557350159]], 'A0021.png': ['non-bleeding', [0.41142430901527405, 0.5885757207870483]], 'A0020.png': ['non-bleeding', [0.41419294476509094, 0.5858070254325867]], 'A0031.png': ['non-bleeding', [0.43158939480781555, 0.5684106349945068]]}

# %%
Image.open("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 1/" + "A0034.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.196-py3-none-any.whl (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 7.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.2)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.15.1)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.196

# %%
from ultralytics import YOLO
import os
os.environ['WANDB_DISABLED'] = 'true'
# Load the model.
model = YOLO('/kaggle/input/cvip-yolo/best.pt')

# %%
valid_results = model.val(iou=0.6)
print(valid_results.box.map)
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# val: Scanning /kaggle/working/dataset/labels/val.cache... 262 images, 0 backgrounds, 0 corrupt: 100%|██████████| 262/262 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:07<00:00,  2.39it/s]
#                    all        262        262      0.725      0.653      0.704      0.413
# Speed: 0.2ms preprocess, 18.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val5
# 0.41263771530088444

# %%
valid_results = model.val(iou=0.65)
print(valid_results.box.map)
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# val: Scanning /kaggle/working/dataset/labels/val.cache... 262 images, 0 backgrounds, 0 corrupt: 100%|██████████| 262/262 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:08<00:00,  1.96it/s]
#                    all        262        262      0.724      0.653      0.706      0.414
# Speed: 0.5ms preprocess, 23.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val7
# 0.4144954432345151

# %%
valid_results
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7de086ebae90>
# fitness: 0.4436026073116444
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([     0.4145])
# names: {0: 'bleeding'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.7244216310306083, 'metrics/recall(B)': 0.6526717557251909, 'metrics/mAP50(B)': 0.7055670840058079, 'metrics/mAP50-95(B)': 0.4144954432345151, 'fitness': 0.4436026073116444}
# save_dir: PosixPath('runs/detect/val7')
# speed: {'preprocess': 0.4990328359239884, 'inference': 23.27688777719745, 'loss': 0.0001910988611119394, 'postprocess': 0.31974661441249697}

# %%
infer = model.predict(source="/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/", conf=0.2, save_conf=True, save_txt=True, save=True)
# Out:
# image 1/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0050.png: 224x224 (no detections), 10.4ms
# image 2/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0051.png: 224x224 (no detections), 5.6ms
# image 3/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0052.png: 224x224 (no detections), 5.5ms
# image 4/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0053.png: 224x224 (no detections), 5.5ms
# image 5/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0054.png: 224x224 (no detections), 5.4ms
# image 6/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0055.png: 224x224 (no detections), 5.6ms
# image 7/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0056.png: 224x224 (no detections), 5.7ms
# image 8/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0057.png: 224x224 (no detections), 5.3ms
# image 9/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0058.png: 224x224 (no detections), 5.4ms
# image 10/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0059.png: 224x224 (no detections), 5.5ms
# image 11/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0060.png: 224x224 1 bleeding, 5.5ms
# image 12/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0061.png: 224x224 (no detections), 5.9ms
# image 13/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0062.png: 224x224 (no detections), 5.6ms
# image 14/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0063.png: 224x224 (no detections), 5.7ms
# image 15/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0064.png: 224x224 (no detections), 7.4ms
# image 16/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0065.png: 224x224 (no detections), 5.4ms
# image 17/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0066.png: 224x224 2 bleedings, 6.6ms
# image 18/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0067.png: 224x224 2 bleedings, 5.4ms
# image 19/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0068.png: 224x224 (no detections), 5.5ms
# image 20/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0069.png: 224x224 (no detections), 5.3ms
# image 21/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0070.png: 224x224 1 bleeding, 5.3ms
# image 22/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0071.png: 224x224 1 bleeding, 5.5ms
# image 23/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0072.png: 224x224 (no detections), 5.6ms
# image 24/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0073.png: 224x224 2 bleedings, 5.4ms
# image 25/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0074.png: 224x224 1 bleeding, 5.9ms
# image 26/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0075.png: 224x224 (no detections), 5.4ms
# image 27/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0076.png: 224x224 (no detections), 5.6ms
# image 28/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0077.png: 224x224 1 bleeding, 5.4ms
# image 29/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0078.png: 224x224 (no detections), 5.5ms
# image 30/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0079.png: 224x224 (no detections), 5.8ms
# image 31/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0080.png: 224x224 (no detections), 5.5ms
# image 32/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0081.png: 224x224 1 bleeding, 5.4ms
# image 33/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0082.png: 224x224 (no detections), 7.1ms
# image 34/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0083.png: 224x224 (no detections), 5.8ms
# image 35/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0084.png: 224x224 (no detections), 5.4ms
# image 36/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0085.png: 224x224 (no detections), 5.5ms
# image 37/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0086.png: 224x224 (no detections), 5.7ms
# image 38/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0087.png: 224x224 (no detections), 16.5ms
# image 39/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0088.png: 224x224 (no detections), 6.9ms
# image 40/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0089.png: 224x224 (no detections), 5.4ms
# image 41/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0090.png: 224x224 (no detections), 5.6ms
# image 42/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0091.png: 224x224 (no detections), 6.1ms
# image 43/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0092.png: 224x224 (no detections), 5.5ms
# image 44/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0093.png: 224x224 (no detections), 5.7ms
# image 45/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0094.png: 224x224 (no detections), 5.9ms
# image 46/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0095.png: 224x224 (no detections), 5.5ms
# image 47/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0096.png: 224x224 (no detections), 5.7ms
# image 48/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0097.png: 224x224 1 bleeding, 5.4ms
# image 49/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0098.png: 224x224 (no detections), 5.3ms
# image 50/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0099.png: 224x224 (no detections), 5.5ms
# image 51/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0100.png: 224x224 (no detections), 5.3ms
# image 52/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0101.png: 224x224 (no detections), 5.6ms
# image 53/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0102.png: 224x224 (no detections), 5.5ms
# image 54/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0103.png: 224x224 (no detections), 5.5ms
# image 55/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0104.png: 224x224 (no detections), 5.5ms
# image 56/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0105.png: 224x224 (no detections), 5.7ms
# image 57/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0106.png: 224x224 (no detections), 5.4ms
# image 58/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0107.png: 224x224 1 bleeding, 5.7ms
# image 59/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0108.png: 224x224 1 bleeding, 5.7ms
# image 60/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0109.png: 224x224 (no detections), 5.4ms
# image 61/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0110.png: 224x224 (no detections), 5.4ms
# image 62/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0111.png: 224x224 2 bleedings, 5.4ms
# image 63/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0112.png: 224x224 1 bleeding, 5.4ms
# image 64/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0113.png: 224x224 (no detections), 5.4ms
# image 65/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0114.png: 224x224 1 bleeding, 5.9ms
# image 66/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0115.png: 224x224 (no detections), 5.4ms
# image 67/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0116.png: 224x224 1 bleeding, 5.5ms
# image 68/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0117.png: 224x224 1 bleeding, 5.5ms
# image 69/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0118.png: 224x224 1 bleeding, 5.4ms
# image 70/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0119.png: 224x224 1 bleeding, 5.6ms
# image 71/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0120.png: 224x224 1 bleeding, 5.5ms
# image 72/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0121.png: 224x224 1 bleeding, 5.6ms
# image 73/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0122.png: 224x224 1 bleeding, 5.8ms
# image 74/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0123.png: 224x224 1 bleeding, 5.7ms
# image 75/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0124.png: 224x224 (no detections), 5.4ms
# image 76/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0125.png: 224x224 (no detections), 5.4ms
# image 77/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0126.png: 224x224 (no detections), 5.5ms
# image 78/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0127.png: 224x224 (no detections), 5.5ms
# image 79/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0128.png: 224x224 (no detections), 5.6ms
# image 80/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0129.png: 224x224 1 bleeding, 5.4ms
# image 81/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0130.png: 224x224 1 bleeding, 5.4ms
# image 82/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0131.png: 224x224 (no detections), 6.1ms
# image 83/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0132.png: 224x224 1 bleeding, 5.8ms
# image 84/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0133.png: 224x224 (no detections), 5.7ms
# image 85/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0134.png: 224x224 (no detections), 5.6ms
# image 86/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0135.png: 224x224 (no detections), 6.1ms
# image 87/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0136.png: 224x224 (no detections), 5.7ms
# image 88/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0137.png: 224x224 (no detections), 6.4ms
# image 89/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0138.png: 224x224 1 bleeding, 5.9ms
# image 90/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0139.png: 224x224 1 bleeding, 5.5ms
# image 91/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0140.png: 224x224 1 bleeding, 5.7ms
# image 92/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0141.png: 224x224 (no detections), 5.5ms
# image 93/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0142.png: 224x224 1 bleeding, 5.4ms
# image 94/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0143.png: 224x224 (no detections), 5.4ms
# image 95/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0144.png: 224x224 (no detections), 5.6ms
# image 96/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0145.png: 224x224 (no detections), 5.4ms
# image 97/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0146.png: 224x224 (no detections), 5.4ms
# image 98/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0147.png: 224x224 (no detections), 5.8ms
# image 99/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0148.png: 224x224 (no detections), 5.4ms
# image 100/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0149.png: 224x224 (no detections), 5.5ms
# image 101/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0150.png: 224x224 1 bleeding, 5.4ms
# image 102/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0151.png: 224x224 (no detections), 5.4ms
# image 103/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0152.png: 224x224 (no detections), 5.4ms
# image 104/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0153.png: 224x224 (no detections), 5.4ms
# image 105/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0154.png: 224x224 (no detections), 5.5ms
# image 106/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0155.png: 224x224 1 bleeding, 5.6ms
# image 107/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0156.png: 224x224 (no detections), 5.4ms
# image 108/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0157.png: 224x224 (no detections), 5.4ms
# image 109/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0158.png: 224x224 (no detections), 5.3ms
# image 110/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0159.png: 224x224 1 bleeding, 5.4ms
# image 111/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0160.png: 224x224 1 bleeding, 5.4ms
# image 112/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0161.png: 224x224 (no detections), 5.3ms
# image 113/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0162.png: 224x224 2 bleedings, 5.5ms
# image 114/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0163.png: 224x224 3 bleedings, 5.4ms
# image 115/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0164.png: 224x224 (no detections), 5.8ms
# image 116/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0165.png: 224x224 (no detections), 5.6ms
# image 117/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0166.png: 224x224 (no detections), 5.3ms
# image 118/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0167.png: 224x224 2 bleedings, 5.3ms
# image 119/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0168.png: 224x224 1 bleeding, 5.5ms
# image 120/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0169.png: 224x224 (no detections), 5.4ms
# image 121/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0170.png: 224x224 (no detections), 5.6ms
# image 122/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0171.png: 224x224 (no detections), 5.4ms
# image 123/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0172.png: 224x224 (no detections), 5.5ms
# image 124/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0173.png: 224x224 (no detections), 5.3ms
# image 125/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0174.png: 224x224 (no detections), 5.5ms
# image 126/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0175.png: 224x224 1 bleeding, 5.4ms
# image 127/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0176.png: 224x224 (no detections), 7.5ms
# image 128/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0177.png: 224x224 (no detections), 5.5ms
# image 129/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0178.png: 224x224 1 bleeding, 5.5ms
# image 130/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0179.png: 224x224 1 bleeding, 5.3ms
# image 131/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0180.png: 224x224 (no detections), 5.2ms
# image 132/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0181.png: 224x224 (no detections), 5.4ms
# image 133/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0182.png: 224x224 (no detections), 5.4ms
# image 134/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0183.png: 224x224 (no detections), 5.3ms
# image 135/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0184.png: 224x224 (no detections), 6.1ms
# image 136/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0185.png: 224x224 (no detections), 6.2ms
# image 137/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0186.png: 224x224 (no detections), 7.0ms
# image 138/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0187.png: 224x224 (no detections), 6.5ms
# image 139/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0188.png: 224x224 (no detections), 6.2ms
# image 140/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0189.png: 224x224 (no detections), 6.1ms
# image 141/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0190.png: 224x224 (no detections), 6.2ms
# image 142/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0191.png: 224x224 1 bleeding, 6.2ms
# image 143/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0192.png: 224x224 2 bleedings, 5.7ms
# image 144/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0193.png: 224x224 (no detections), 5.4ms
# image 145/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0194.png: 224x224 1 bleeding, 5.5ms
# image 146/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0195.png: 224x224 (no detections), 5.6ms
# image 147/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0196.png: 224x224 1 bleeding, 5.5ms
# image 148/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0197.png: 224x224 (no detections), 5.4ms
# image 149/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0198.png: 224x224 (no detections), 5.4ms
# image 150/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0199.png: 224x224 1 bleeding, 5.7ms
# image 151/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0200.png: 224x224 (no detections), 5.4ms
# image 152/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0201.png: 224x224 (no detections), 5.6ms
# image 153/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0202.png: 224x224 1 bleeding, 5.5ms
# image 154/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0203.png: 224x224 1 bleeding, 5.4ms
# image 155/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0204.png: 224x224 1 bleeding, 5.4ms
# image 156/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0205.png: 224x224 1 bleeding, 5.3ms
# image 157/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0206.png: 224x224 1 bleeding, 5.4ms
# image 158/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0207.png: 224x224 (no detections), 5.4ms
# image 159/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0208.png: 224x224 (no detections), 5.6ms
# image 160/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0209.png: 224x224 1 bleeding, 5.4ms
# image 161/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0210.png: 224x224 1 bleeding, 5.5ms
# image 162/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0211.png: 224x224 (no detections), 5.7ms
# image 163/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0212.png: 224x224 1 bleeding, 5.4ms
# image 164/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0213.png: 224x224 1 bleeding, 5.4ms
# image 165/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0214.png: 224x224 1 bleeding, 5.5ms
# image 166/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0215.png: 224x224 1 bleeding, 5.3ms
# image 167/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0216.png: 224x224 (no detections), 5.3ms
# image 168/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0217.png: 224x224 (no detections), 5.7ms
# image 169/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0218.png: 224x224 (no detections), 5.3ms
# image 170/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0219.png: 224x224 (no detections), 5.4ms
# image 171/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0220.png: 224x224 (no detections), 5.3ms
# image 172/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0221.png: 224x224 (no detections), 5.4ms
# image 173/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0222.png: 224x224 (no detections), 5.7ms
# image 174/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0223.png: 224x224 (no detections), 5.3ms
# image 175/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0224.png: 224x224 (no detections), 5.4ms
# image 176/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0225.png: 224x224 (no detections), 5.3ms
# image 177/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0226.png: 224x224 (no detections), 5.3ms
# image 178/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0227.png: 224x224 (no detections), 5.7ms
# image 179/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0228.png: 224x224 (no detections), 5.3ms
# image 180/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0229.png: 224x224 (no detections), 5.4ms
# image 181/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0230.png: 224x224 (no detections), 5.4ms
# image 182/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0231.png: 224x224 (no detections), 5.4ms
# image 183/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0232.png: 224x224 (no detections), 6.0ms
# image 184/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0233.png: 224x224 (no detections), 5.4ms
# image 185/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0234.png: 224x224 (no detections), 5.3ms
# image 186/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0235.png: 224x224 1 bleeding, 5.3ms
# image 187/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0236.png: 224x224 (no detections), 5.4ms
# image 188/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0237.png: 224x224 2 bleedings, 5.3ms
# image 189/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0238.png: 224x224 (no detections), 5.3ms
# image 190/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0239.png: 224x224 1 bleeding, 5.3ms
# image 191/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0240.png: 224x224 (no detections), 5.3ms
# image 192/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0241.png: 224x224 1 bleeding, 5.4ms
# image 193/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0242.png: 224x224 1 bleeding, 5.3ms
# image 194/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0243.png: 224x224 2 bleedings, 5.4ms
# image 195/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0244.png: 224x224 1 bleeding, 5.3ms
# image 196/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0245.png: 224x224 (no detections), 5.3ms
# image 197/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0246.png: 224x224 1 bleeding, 5.4ms
# image 198/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0247.png: 224x224 (no detections), 5.7ms
# image 199/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0248.png: 224x224 1 bleeding, 5.3ms
# image 200/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0249.png: 224x224 (no detections), 5.6ms
# image 201/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0250.png: 224x224 (no detections), 5.3ms
# image 202/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0251.png: 224x224 (no detections), 5.2ms
# image 203/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0252.png: 224x224 (no detections), 5.7ms
# image 204/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0253.png: 224x224 (no detections), 5.5ms
# image 205/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0254.png: 224x224 (no detections), 5.3ms
# image 206/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0255.png: 224x224 1 bleeding, 5.3ms
# image 207/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0256.png: 224x224 1 bleeding, 5.3ms
# image 208/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0257.png: 224x224 (no detections), 5.4ms
# image 209/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0258.png: 224x224 (no detections), 5.4ms
# image 210/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0259.png: 224x224 (no detections), 5.5ms
# image 211/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0260.png: 224x224 1 bleeding, 5.3ms
# image 212/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0261.png: 224x224 (no detections), 5.5ms
# image 213/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0262.png: 224x224 (no detections), 5.4ms
# image 214/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0263.png: 224x224 1 bleeding, 5.4ms
# image 215/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0264.png: 224x224 (no detections), 5.4ms
# image 216/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0265.png: 224x224 (no detections), 5.3ms
# image 217/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0266.png: 224x224 (no detections), 5.5ms
# image 218/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0267.png: 224x224 (no detections), 5.4ms
# image 219/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0268.png: 224x224 (no detections), 5.4ms
# image 220/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0269.png: 224x224 1 bleeding, 5.3ms
# image 221/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0270.png: 224x224 (no detections), 9.4ms
# image 222/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0271.png: 224x224 (no detections), 6.0ms
# image 223/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0272.png: 224x224 (no detections), 5.3ms
# image 224/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0273.png: 224x224 1 bleeding, 5.9ms
# image 225/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0274.png: 224x224 (no detections), 5.3ms
# image 226/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0275.png: 224x224 (no detections), 5.3ms
# image 227/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0276.png: 224x224 (no detections), 5.4ms
# image 228/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0277.png: 224x224 1 bleeding, 5.3ms
# image 229/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0278.png: 224x224 (no detections), 5.3ms
# image 230/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0279.png: 224x224 1 bleeding, 5.4ms
# image 231/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0280.png: 224x224 (no detections), 6.2ms
# image 232/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0281.png: 224x224 (no detections), 5.3ms
# image 233/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0282.png: 224x224 (no detections), 5.7ms
# image 234/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0283.png: 224x224 1 bleeding, 5.5ms
# image 235/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0284.png: 224x224 1 bleeding, 5.2ms
# image 236/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0285.png: 224x224 (no detections), 5.2ms
# image 237/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0286.png: 224x224 (no detections), 5.3ms
# image 238/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0287.png: 224x224 (no detections), 5.6ms
# image 239/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0288.png: 224x224 (no detections), 5.2ms
# image 240/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0289.png: 224x224 (no detections), 5.5ms
# image 241/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0290.png: 224x224 (no detections), 5.7ms
# image 242/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0291.png: 224x224 (no detections), 5.5ms
# image 243/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0292.png: 224x224 (no detections), 5.3ms
# image 244/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0293.png: 224x224 1 bleeding, 5.3ms
# image 245/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0294.png: 224x224 (no detections), 5.5ms
# image 246/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0295.png: 224x224 (no detections), 5.4ms
# image 247/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0296.png: 224x224 (no detections), 5.6ms
# image 248/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0297.png: 224x224 1 bleeding, 5.3ms
# image 249/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0298.png: 224x224 1 bleeding, 5.5ms
# image 250/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0299.png: 224x224 1 bleeding, 5.4ms
# image 251/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0300.png: 224x224 (no detections), 5.4ms
# image 252/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0301.png: 224x224 (no detections), 5.7ms
# image 253/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0302.png: 224x224 1 bleeding, 5.3ms
# image 254/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0303.png: 224x224 (no detections), 5.6ms
# image 255/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0304.png: 224x224 (no detections), 5.6ms
# image 256/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0305.png: 224x224 (no detections), 5.4ms
# image 257/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0306.png: 224x224 (no detections), 5.6ms
# image 258/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0307.png: 224x224 1 bleeding, 5.4ms
# image 259/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0308.png: 224x224 1 bleeding, 5.5ms
# image 260/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0309.png: 224x224 (no detections), 5.6ms
# image 261/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0310.png: 224x224 (no detections), 5.4ms
# image 262/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0311.png: 224x224 2 bleedings, 5.4ms
# image 263/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0312.png: 224x224 1 bleeding, 5.4ms
# image 264/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0313.png: 224x224 (no detections), 5.4ms
# image 265/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0314.png: 224x224 (no detections), 5.6ms
# image 266/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0315.png: 224x224 (no detections), 5.6ms
# image 267/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0316.png: 224x224 (no detections), 5.4ms
# image 268/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0317.png: 224x224 (no detections), 5.5ms
# image 269/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0318.png: 224x224 1 bleeding, 5.3ms
# image 270/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0319.png: 224x224 (no detections), 5.9ms
# image 271/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0320.png: 224x224 (no detections), 5.8ms
# image 272/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0321.png: 224x224 (no detections), 5.3ms
# image 273/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0322.png: 224x224 1 bleeding, 5.8ms
# image 274/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0323.png: 224x224 (no detections), 5.4ms
# image 275/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0324.png: 224x224 (no detections), 5.4ms
# image 276/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0325.png: 224x224 1 bleeding, 5.4ms
# image 277/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0326.png: 224x224 (no detections), 5.4ms
# image 278/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0327.png: 224x224 (no detections), 5.3ms
# image 279/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0328.png: 224x224 1 bleeding, 5.8ms
# image 280/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0329.png: 224x224 1 bleeding, 5.5ms
# image 281/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0330.png: 224x224 1 bleeding, 5.5ms
# image 282/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0331.png: 224x224 1 bleeding, 5.2ms
# image 283/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0332.png: 224x224 (no detections), 5.5ms
# image 284/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0333.png: 224x224 1 bleeding, 5.3ms
# image 285/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0334.png: 224x224 (no detections), 5.5ms
# image 286/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0335.png: 224x224 1 bleeding, 5.2ms
# image 287/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0336.png: 224x224 1 bleeding, 5.4ms
# image 288/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0337.png: 224x224 (no detections), 5.5ms
# image 289/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0338.png: 224x224 (no detections), 5.4ms
# image 290/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0339.png: 224x224 (no detections), 5.6ms
# image 291/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0340.png: 224x224 (no detections), 5.3ms
# image 292/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0341.png: 224x224 (no detections), 5.3ms
# image 293/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0342.png: 224x224 (no detections), 5.3ms
# image 294/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0343.png: 224x224 (no detections), 5.7ms
# image 295/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0344.png: 224x224 (no detections), 5.8ms
# image 296/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0345.png: 224x224 (no detections), 5.3ms
# image 297/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0346.png: 224x224 (no detections), 5.3ms
# image 298/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0347.png: 224x224 (no detections), 5.3ms
# image 299/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0348.png: 224x224 2 bleedings, 5.4ms
# image 300/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0349.png: 224x224 (no detections), 5.6ms
# image 301/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0350.png: 224x224 1 bleeding, 5.5ms
# image 302/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0351.png: 224x224 1 bleeding, 5.3ms
# image 303/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0352.png: 224x224 (no detections), 5.3ms
# image 304/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0353.png: 224x224 1 bleeding, 5.3ms
# image 305/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0354.png: 224x224 (no detections), 5.8ms
# image 306/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0355.png: 224x224 1 bleeding, 5.3ms
# image 307/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0356.png: 224x224 (no detections), 5.4ms
# image 308/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0357.png: 224x224 (no detections), 5.4ms
# image 309/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0358.png: 224x224 (no detections), 5.2ms
# image 310/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0359.png: 224x224 (no detections), 5.7ms
# image 311/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0360.png: 224x224 2 bleedings, 5.5ms
# image 312/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0361.png: 224x224 1 bleeding, 6.0ms
# image 313/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0362.png: 224x224 1 bleeding, 5.4ms
# image 314/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0363.png: 224x224 1 bleeding, 5.3ms
# image 315/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0364.png: 224x224 (no detections), 5.6ms
# image 316/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0365.png: 224x224 (no detections), 5.3ms
# image 317/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0366.png: 224x224 (no detections), 5.4ms
# image 318/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0367.png: 224x224 (no detections), 5.4ms
# image 319/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0368.png: 224x224 (no detections), 5.4ms
# image 320/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0369.png: 224x224 1 bleeding, 5.6ms
# image 321/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0370.png: 224x224 (no detections), 5.3ms
# image 322/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0371.png: 224x224 (no detections), 5.4ms
# image 323/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0372.png: 224x224 1 bleeding, 5.3ms
# image 324/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0373.png: 224x224 (no detections), 5.3ms
# image 325/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0374.png: 224x224 2 bleedings, 5.7ms
# image 326/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0375.png: 224x224 1 bleeding, 5.4ms
# image 327/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0376.png: 224x224 (no detections), 5.3ms
# image 328/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0377.png: 224x224 2 bleedings, 5.2ms
# image 329/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0378.png: 224x224 (no detections), 5.6ms
# image 330/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0379.png: 224x224 (no detections), 5.5ms
# image 331/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0380.png: 224x224 2 bleedings, 5.4ms
# image 332/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0381.png: 224x224 1 bleeding, 6.4ms
# image 333/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0382.png: 224x224 3 bleedings, 5.6ms
# image 334/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0383.png: 224x224 2 bleedings, 5.3ms
# image 335/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0384.png: 224x224 1 bleeding, 5.3ms
# image 336/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0385.png: 224x224 1 bleeding, 5.4ms
# image 337/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0386.png: 224x224 1 bleeding, 5.5ms
# image 338/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0387.png: 224x224 (no detections), 5.5ms
# image 339/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0388.png: 224x224 (no detections), 5.2ms
# image 340/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0389.png: 224x224 (no detections), 5.4ms
# image 341/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0390.png: 224x224 (no detections), 5.4ms
# image 342/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0391.png: 224x224 (no detections), 5.3ms
# image 343/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0392.png: 224x224 1 bleeding, 5.3ms
# image 344/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0393.png: 224x224 (no detections), 5.3ms
# image 345/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0394.png: 224x224 (no detections), 5.5ms
# image 346/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0395.png: 224x224 (no detections), 5.3ms
# image 347/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0396.png: 224x224 (no detections), 5.2ms
# image 348/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0397.png: 224x224 1 bleeding, 5.2ms
# image 349/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0398.png: 224x224 1 bleeding, 5.3ms
# image 350/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0399.png: 224x224 (no detections), 5.5ms
# ...
# image 401/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0450.png: 224x224 1 bleeding, 5.5ms
# image 402/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0451.png: 224x224 (no detections), 5.3ms
# image 403/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0452.png: 224x224 (no detections), 5.6ms
# image 404/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0453.png: 224x224 (no detections), 5.3ms
# image 405/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0454.png: 224x224 (no detections), 5.3ms
# image 406/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0455.png: 224x224 1 bleeding, 5.3ms
# image 407/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0456.png: 224x224 (no detections), 5.3ms
# image 408/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0457.png: 224x224 (no detections), 5.4ms
# image 409/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0458.png: 224x224 (no detections), 5.3ms
# image 410/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0459.png: 224x224 (no detections), 5.7ms
# image 411/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0460.png: 224x224 (no detections), 5.4ms
# image 412/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0461.png: 224x224 (no detections), 5.7ms
# image 413/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0462.png: 224x224 (no detections), 5.7ms
# image 414/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0463.png: 224x224 (no detections), 5.9ms
# image 415/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0464.png: 224x224 1 bleeding, 5.3ms
# image 416/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0465.png: 224x224 1 bleeding, 5.3ms
# image 417/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0466.png: 224x224 (no detections), 7.3ms
# image 418/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0467.png: 224x224 1 bleeding, 5.4ms
# image 419/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0468.png: 224x224 1 bleeding, 5.3ms
# image 420/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0469.png: 224x224 1 bleeding, 5.3ms
# image 421/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0470.png: 224x224 (no detections), 5.3ms
# image 422/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0471.png: 224x224 1 bleeding, 5.3ms
# image 423/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0472.png: 224x224 (no detections), 5.5ms
# image 424/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0473.png: 224x224 (no detections), 5.5ms
# image 425/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0474.png: 224x224 (no detections), 5.4ms
# image 426/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0475.png: 224x224 (no detections), 5.3ms
# image 427/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0476.png: 224x224 (no detections), 5.4ms
# image 428/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0477.png: 224x224 2 bleedings, 5.4ms
# image 429/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0478.png: 224x224 1 bleeding, 5.3ms
# image 430/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0479.png: 224x224 1 bleeding, 5.4ms
# image 431/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0480.png: 224x224 (no detections), 5.3ms
# image 432/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0481.png: 224x224 (no detections), 5.3ms
# image 433/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0482.png: 224x224 (no detections), 5.5ms
# image 434/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0483.png: 224x224 (no detections), 5.6ms
# image 435/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0484.png: 224x224 1 bleeding, 5.3ms
# image 436/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0485.png: 224x224 1 bleeding, 5.5ms
# image 437/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0486.png: 224x224 1 bleeding, 5.4ms
# image 438/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0487.png: 224x224 (no detections), 5.3ms
# image 439/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0488.png: 224x224 (no detections), 5.5ms
# image 440/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0489.png: 224x224 (no detections), 5.5ms
# image 441/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0490.png: 224x224 (no detections), 5.6ms
# image 442/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0491.png: 224x224 (no detections), 5.5ms
# image 443/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0492.png: 224x224 (no detections), 5.6ms
# image 444/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0493.png: 224x224 (no detections), 5.6ms
# image 445/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0494.png: 224x224 1 bleeding, 5.4ms
# image 446/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0495.png: 224x224 1 bleeding, 5.3ms
# image 447/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0496.png: 224x224 (no detections), 5.3ms
# image 448/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0497.png: 224x224 1 bleeding, 5.2ms
# image 449/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0498.png: 224x224 1 bleeding, 5.7ms
# image 450/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0499.png: 224x224 2 bleedings, 5.5ms
# image 451/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0500.png: 224x224 (no detections), 5.5ms
# image 452/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0501.png: 224x224 (no detections), 5.3ms
# image 453/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0502.png: 224x224 (no detections), 5.5ms
# image 454/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0503.png: 224x224 (no detections), 5.7ms
# image 455/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0504.png: 224x224 (no detections), 5.3ms
# image 456/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0505.png: 224x224 (no detections), 5.5ms
# image 457/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0506.png: 224x224 1 bleeding, 5.5ms
# image 458/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0507.png: 224x224 1 bleeding, 5.5ms
# image 459/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0508.png: 224x224 1 bleeding, 5.9ms
# image 460/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0509.png: 224x224 (no detections), 5.4ms
# image 461/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0510.png: 224x224 (no detections), 5.3ms
# image 462/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0511.png: 224x224 (no detections), 5.4ms
# image 463/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0512.png: 224x224 (no detections), 5.2ms
# image 464/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0513.png: 224x224 (no detections), 5.3ms
# image 465/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0514.png: 224x224 (no detections), 5.6ms
# image 466/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0515.png: 224x224 (no detections), 5.3ms
# image 467/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0516.png: 224x224 (no detections), 7.8ms
# image 468/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0517.png: 224x224 (no detections), 5.6ms
# image 469/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0518.png: 224x224 (no detections), 5.3ms
# image 470/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0519.png: 224x224 (no detections), 5.4ms
# image 471/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0520.png: 224x224 (no detections), 5.4ms
# image 472/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0521.png: 224x224 1 bleeding, 5.3ms
# image 473/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0522.png: 224x224 1 bleeding, 5.4ms
# image 474/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0523.png: 224x224 (no detections), 5.3ms
# image 475/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0524.png: 224x224 1 bleeding, 5.3ms
# image 476/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0525.png: 224x224 1 bleeding, 6.1ms
# image 477/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0526.png: 224x224 (no detections), 5.6ms
# image 478/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0527.png: 224x224 (no detections), 5.5ms
# image 479/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0528.png: 224x224 (no detections), 5.6ms
# image 480/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0529.png: 224x224 (no detections), 5.4ms
# image 481/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0530.png: 224x224 (no detections), 5.4ms
# image 482/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0531.png: 224x224 (no detections), 5.3ms
# image 483/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0532.png: 224x224 2 bleedings, 5.3ms
# image 484/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0533.png: 224x224 (no detections), 5.5ms
# image 485/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0534.png: 224x224 1 bleeding, 5.3ms
# image 486/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0535.png: 224x224 (no detections), 5.3ms
# image 487/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0536.png: 224x224 (no detections), 5.3ms
# image 488/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0537.png: 224x224 1 bleeding, 5.3ms
# image 489/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0538.png: 224x224 (no detections), 5.3ms
# image 490/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0539.png: 224x224 (no detections), 5.3ms
# image 491/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0540.png: 224x224 1 bleeding, 5.3ms
# image 492/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0541.png: 224x224 1 bleeding, 5.2ms
# image 493/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0542.png: 224x224 (no detections), 5.3ms
# image 494/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0543.png: 224x224 2 bleedings, 5.3ms
# image 495/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0544.png: 224x224 (no detections), 5.3ms
# image 496/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0545.png: 224x224 1 bleeding, 7.0ms
# image 497/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0546.png: 224x224 (no detections), 5.4ms
# image 498/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0547.png: 224x224 1 bleeding, 5.2ms
# image 499/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0548.png: 224x224 (no detections), 5.8ms
# image 500/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0549.png: 224x224 (no detections), 5.7ms
# image 501/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0550.png: 224x224 (no detections), 5.3ms
# image 502/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0551.png: 224x224 (no detections), 5.3ms
# image 503/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0552.png: 224x224 (no detections), 5.4ms
# image 504/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0553.png: 224x224 (no detections), 5.4ms
# image 505/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0554.png: 224x224 (no detections), 12.5ms
# image 506/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0555.png: 224x224 (no detections), 5.6ms
# image 507/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0556.png: 224x224 (no detections), 8.9ms
# image 508/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0557.png: 224x224 (no detections), 5.3ms
# image 509/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0558.png: 224x224 1 bleeding, 5.6ms
# image 510/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0559.png: 224x224 (no detections), 5.5ms
# image 511/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0560.png: 224x224 1 bleeding, 5.4ms
# image 512/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0561.png: 224x224 1 bleeding, 5.5ms
# image 513/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0562.png: 224x224 (no detections), 5.3ms
# image 514/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0563.png: 224x224 (no detections), 5.3ms
# image 515/515 /kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/A0564.png: 224x224 (no detections), 5.3ms
# Speed: 0.4ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict
# 171 labels saved to runs/detect/predict/labels

# %%
infer

# %%
Image.open("runs/detect/predict/A0038.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
infer

# %%
import os 
testbleed2infer = sorted(os.listdir("/kaggle/input/testbleedyolo/Auto-WCEBleedGen Challenge Test Dataset/Test Dataset 2/"))
testbleed2inferdict = {}
count = 0
for a in testbleed2infer:
    try:
        with open("/kaggle/working/runs/detect/predict/labels/"+a.split(".")[0]+".txt", 'r') as f:
            temp = []
            for r in f.readlines():
                temp.append(r.split("\n")[0].split(' ')[-1])
            testbleed2inferdict[a] = max(temp)
#             print(a, [r.split("\n")[0] for r in f.readlines()], sep=', ')
            count = count+1
    except:
        continue

# %%
# testbleed2inferdict
testbleed2inferdictsorted = sorted(testbleed2inferdict.items(), key=lambda x:x[1], reverse=True)

# %%
testbleed2inferdictsorted
# Out:
# [('A0123.png', '0.912617'),
#  ('A0375.png', '0.820615'),
#  ('A0279.png', '0.746522'),
#  ('A0071.png', '0.721107'),
#  ('A0329.png', '0.698805'),
#  ('A0081.png', '0.685299'),
#  ('A0246.png', '0.684787'),
#  ('A0424.png', '0.639733'),
#  ('A0114.png', '0.61618'),
#  ('A0067.png', '0.601629'),
#  ('A0353.png', '0.582982'),
#  ('A0467.png', '0.58237'),
#  ('A0117.png', '0.579305'),
#  ('A0330.png', '0.57366'),
#  ('A0372.png', '0.561274'),
#  ('A0469.png', '0.56037'),
#  ('A0477.png', '0.546169'),
#  ('A0397.png', '0.545235'),
#  ('A0132.png', '0.542071'),
#  ('A0333.png', '0.534872'),
#  ('A0445.png', '0.533482'),
#  ('A0450.png', '0.530968'),
#  ('A0162.png', '0.528513'),
#  ('A0427.png', '0.524379'),
#  ('A0440.png', '0.52038'),
#  ('A0121.png', '0.511225'),
#  ('A0498.png', '0.50139'),
#  ('A0118.png', '0.486182'),
#  ('A0468.png', '0.482741'),
#  ('A0360.png', '0.467463'),
#  ('A0383.png', '0.464302'),
#  ('A0382.png', '0.462564'),
#  ('A0241.png', '0.458776'),
#  ('A0283.png', '0.458776'),
#  ('A0269.png', '0.44892'),
#  ('A0215.png', '0.446141'),
#  ('A0322.png', '0.437696'),
#  ('A0455.png', '0.434605'),
#  ('A0293.png', '0.431865'),
#  ('A0540.png', '0.431176'),
#  ('A0484.png', '0.424117'),
#  ('A0244.png', '0.423634'),
#  ('A0336.png', '0.422709'),
#  ('A0380.png', '0.421431'),
#  ('A0129.png', '0.413892'),
#  ('A0243.png', '0.41377'),
#  ('A0422.png', '0.406314'),
#  ('A0212.png', '0.405128'),
#  ('A0107.png', '0.400834'),
#  ('A0439.png', '0.395434'),
#  ('A0412.png', '0.393624'),
#  ('A0160.png', '0.383653'),
#  ('A0108.png', '0.383095'),
#  ('A0167.png', '0.377547'),
#  ('A0297.png', '0.375205'),
#  ('A0350.png', '0.371814'),
#  ('A0384.png', '0.370583'),
#  ('A0398.png', '0.369824'),
#  ('A0235.png', '0.366209'),
#  ('A0214.png', '0.365025'),
#  ('A0298.png', '0.360704'),
#  ('A0541.png', '0.35468'),
#  ('A0312.png', '0.351255'),
#  ('A0237.png', '0.348383'),
#  ('A0478.png', '0.342941'),
#  ('A0299.png', '0.334592'),
#  ('A0210.png', '0.332813'),
#  ('A0277.png', '0.331586'),
#  ('A0178.png', '0.330966'),
#  ('A0116.png', '0.330167'),
#  ('A0386.png', '0.324112'),
#  ('A0284.png', '0.321129'),
#  ('A0479.png', '0.320633'),
#  ('A0558.png', '0.319064'),
#  ('A0204.png', '0.318329'),
#  ('A0430.png', '0.310728'),
#  ('A0120.png', '0.309293'),
#  ('A0532.png', '0.305537'),
#  ('A0066.png', '0.303759'),
#  ('A0407.png', '0.303603'),
#  ('A0543.png', '0.303406'),
#  ('A0209.png', '0.302015'),
#  ('A0163.png', '0.300747'),
#  ('A0155.png', '0.298676'),
#  ('A0122.png', '0.298437'),
#  ('A0392.png', '0.295473'),
#  ('A0119.png', '0.293685'),
#  ('A0112.png', '0.292908'),
#  ('A0260.png', '0.291292'),
#  ('A0256.png', '0.290059'),
#  ('A0073.png', '0.286971'),
#  ('A0545.png', '0.285012'),
#  ('A0150.png', '0.280693'),
#  ('A0060.png', '0.280386'),
#  ('A0447.png', '0.279335'),
#  ('A0199.png', '0.278629'),
#  ('A0381.png', '0.278057'),
#  ('A0508.png', '0.276228'),
#  ('A0325.png', '0.275529'),
#  ('A0408.png', '0.268458'),
#  ('A0495.png', '0.265161'),
#  ('A0318.png', '0.264577'),
#  ('A0139.png', '0.262907'),
#  ('A0191.png', '0.262277'),
#  ('A0374.png', '0.259051'),
#  ('A0242.png', '0.251792'),
#  ('A0111.png', '0.251616'),
#  ('A0438.png', '0.250802'),
#  ('A0560.png', '0.250641'),
#  ('A0348.png', '0.250024'),
#  ('A0206.png', '0.248333'),
#  ('A0524.png', '0.243257'),
#  ('A0273.png', '0.241737'),
#  ('A0202.png', '0.240159'),
#  ('A0335.png', '0.240061'),
#  ('A0203.png', '0.239906'),
#  ('A0142.png', '0.238257'),
#  ('A0465.png', '0.238093'),
#  ('A0194.png', '0.236876'),
#  ('A0328.png', '0.236782'),
#  ('A0547.png', '0.236248'),
#  ('A0070.png', '0.235669'),
#  ('A0263.png', '0.235418'),
#  ('A0377.png', '0.235111'),
#  ('A0248.png', '0.234576'),
#  ('A0522.png', '0.234511'),
#  ('A0537.png', '0.233931'),
#  ('A0351.png', '0.233735'),
#  ('A0486.png', '0.232174'),
#  ('A0485.png', '0.229165'),
#  ('A0168.png', '0.228125'),
#  ('A0196.png', '0.226108'),
#  ('A0175.png', '0.22581'),
#  ('A0385.png', '0.224749'),
#  ('A0355.png', '0.223849'),
#  ('A0205.png', '0.223491'),
#  ('A0561.png', '0.223164'),
#  ('A0179.png', '0.222686'),
#  ('A0074.png', '0.222612'),
#  ('A0239.png', '0.220464'),
#  ('A0363.png', '0.219954'),
#  ('A0446.png', '0.219776'),
#  ('A0506.png', '0.217109'),
#  ('A0255.png', '0.21687'),
#  ('A0192.png', '0.216051'),
#  ('A0311.png', '0.215693'),
#  ('A0400.png', '0.214029'),
#  ('A0331.png', '0.21213'),
#  ('A0159.png', '0.211786'),
#  ('A0140.png', '0.211778'),
#  ('A0361.png', '0.210901'),
#  ('A0443.png', '0.210851'),
#  ('A0525.png', '0.210009'),
#  ('A0077.png', '0.208212'),
#  ('A0130.png', '0.208159'),
#  ('A0521.png', '0.207537'),
#  ('A0499.png', '0.207305'),
#  ('A0302.png', '0.206067'),
#  ('A0464.png', '0.20595'),
#  ('A0213.png', '0.205811'),
#  ('A0507.png', '0.205358'),
#  ('A0362.png', '0.205224'),
#  ('A0307.png', '0.205183'),
#  ('A0494.png', '0.205052'),
#  ('A0497.png', '0.204447'),
#  ('A0138.png', '0.203536'),
#  ('A0097.png', '0.203428'),
#  ('A0534.png', '0.202265'),
#  ('A0471.png', '0.202193'),
#  ('A0308.png', '0.201837'),
#  ('A0369.png', '0.201066')]

# %%
sorted_dict2['A0040.png']
# Out:
# ['bleeding', [0.9803436994552612, 0.019656337797641754]]

# %%
print(sorted_dict2['A0036.png'])
# Out:
# ['bleeding', [0.9938283562660217, 0.006171696819365025]]

# %%
testbleed2inferdictsorted

# %%
count
# Out:
# 171

# %%
# !rm -rf /kaggle/working/runs/detect/predict4/*

# %%
from PIL import Image
Image.open("/kaggle/working/runs/detect/predict/A0467.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
Image.open("/kaggle/working/runs/detect/predict2/A0375.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
Image.open("/kaggle/working/runs/detect/predict2/A0279.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
Image.open("/kaggle/working/runs/detect/predict2/A0071.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
Image.open("/kaggle/working/runs/detect/predict2/A0329.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
# !ls /kaggle/working/runs/detect/val7/
# Out:
# F1_curve.png  confusion_matrix.png	       val_batch1_labels.jpg
# PR_curve.png  confusion_matrix_normalized.png  val_batch1_pred.jpg
# P_curve.png   val_batch0_labels.jpg	       val_batch2_labels.jpg
# R_curve.png   val_batch0_pred.jpg	       val_batch2_pred.jpg

# %%
Image.open("/kaggle/working/runs/detect/val7/val_batch1_pred.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
